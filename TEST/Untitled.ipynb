# %%
# !pip install ipython-sql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 692.0 kB/s eta 0:00:000:00:01
# ...

# %%
# %load_ext sql

# %%
# %sql 
CREATE TABLE ABC 
(
ID varchar(20) PRIMARY KEY,
name varchar(20)
);

SELECT * FROM ABC;
# Out:
#   Cell In[16], line 2
#     CREATE TABLE ABC
#            ^
# SyntaxError: invalid syntax
